# %%
import os

import pandas as pd

from utils.signal_analysis import plot_interpolated_df

# %%
df = pd.read_csv(r'database\signals-interpolated\1006.csv')
plot_interpolated_df(df, col='FHR')

# %%
df = pd.read_csv(r'database\signals-interpolated\1001.csv')
plot_interpolated_df(df, col='FHR')

# %%
plot_interpolated_df(
    pd.read_csv(r'database-interpolated\1122.csv'), 
    col='FHR'
)

# %%
plot_interpolated_df(
    pd.read_csv(r'database-interpolated\1417.csv'), 
    col='FHR'
)

# %%
plot_interpolated_df(
    pd.read_csv(r'database-interpolated\2001.csv'), 
    col='FHR'
)
