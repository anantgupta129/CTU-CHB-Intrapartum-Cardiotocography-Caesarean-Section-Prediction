# %% [markdown]
# # Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import xgboost as xgb

# %%
df = pd.read_csv(r'final-interpolated.csv')
df
# Out:
#      Unnamed: 0           ID        pH  ...    Peak_FHR     Peak_UC  target
# 0             0  1220.000000  7.300000  ...  193.000000  127.000000     1.0
# 1             1  1234.000000  7.290000  ...  224.000000  127.000000     1.0
# 2             2  1208.000000  7.230000  ...  174.500000  100.000000     1.0
# 3             3  1038.000000  7.330000  ...  166.750000  100.000000     1.0
# 4             4  1004.000000  7.300000  ...  229.000000  123.000000     1.0
# ..          ...          ...       ...  ...         ...         ...     ...
# 970         970  1612.415502  7.277141  ...  200.142902   91.785073     0.0
# 971         971  1767.337796  7.293675  ...  199.605552   99.390650     0.0
# 972         972  1481.788323  7.230459  ...  187.137600  103.944945     0.0
# 973         973  1199.005821  7.233021  ...  201.576821   71.489613     0.0
# 974         974  1654.971118  7.281683  ...  199.995298   93.874249     0.0
#
# [975 rows x 44 columns]

# %%
# droping unnecessary columns
df.drop(['Unnamed: 0', 'ID'], axis=1, inplace=True)

# %%
df.isnull().sum().sum()  # checking for null values
# Out:
# 0

# %%
df
# Out:
#            pH     BDecf      pCO2  ...    Peak_FHR     Peak_UC  target
# 0    7.300000  3.520000  6.000000  ...  193.000000  127.000000     1.0
# 1    7.290000  2.500000  6.500000  ...  224.000000  127.000000     1.0
# 2    7.230000  5.840000  6.600000  ...  174.500000  100.000000     1.0
# 3    7.330000  2.720000  5.700000  ...  166.750000  100.000000     1.0
# 4    7.300000  5.190000  5.500000  ...  229.000000  123.000000     1.0
# ..        ...       ...       ...  ...         ...         ...     ...
# 970  7.277141  4.170062  6.214293  ...  200.142902   91.785073     0.0
# 971  7.293675  3.440918  6.131623  ...  199.605552   99.390650     0.0
# 972  7.230459  4.115599  7.287158  ...  187.137600  103.944945     0.0
# 973  7.233021  6.115778  6.434896  ...  201.576821   71.489613     0.0
# 974  7.281683  3.969773  6.191584  ...  199.995298   93.874249     0.0
#
# [975 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['pH', 'BDecf', 'pCO2', 'BE', 'Apgar1', 'Apgar5', 'Gest. Weeks',
#        'Weight(g)', 'Sex', 'Age', 'Gravidity', 'Parity', 'Diabetes',
#        'Hypertension', 'Preeclampsia', 'Liq.', 'Pyrexia', 'Meconium',
#        'Presentation', 'Induced', 'I.stage', 'NoProgress', 'CK/KP', 'II.stage',
#        'Deliv. type', 'dbID', 'Rec. type', 'Pos. II.st.', 'Sig2Birth',
#        'Mean_FHR', 'Mean_UC', 'Median_FHR', 'Median_UC', 'Std_FHR', 'Std_UC',
#        'RMS_FHR', 'RMS_UC', 'Peak_to_RMS_FHR', 'Peak_to_RMS_UC', 'Peak_FHR',
#        'Peak_UC', 'target'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %%
def f(x):
    if 6.5<x<=10:
        return  'Excellent'
    elif 4<x<=6.5:
        return 'ModeratelyAbnormal'
    elif x<=4:
        return 'Attention'

df['Apgar1'] = df['Apgar1'].apply(lambda x: f(x))

# %%
df['Apgar5'] = df['Apgar5'].apply(lambda x: f(x))

# %%
df.Apgar1.value_counts()
# Out:
# Excellent             901
# ModeratelyAbnormal     47
# Attention              27
# Name: Apgar1, dtype: int64

# %%
df.Apgar5.value_counts()
# Out:
# Excellent             957
# ModeratelyAbnormal     15
# Attention               3
# Name: Apgar5, dtype: int64

# %%
df.target.value_counts()
# Out:
# 1.0    488
# 0.0    487
# Name: target, dtype: int64

# %%
df['pH'] = df['pH'].apply(lambda x: 'Pathological' if x<=7.15 else 'Normal')
df
# Out:
#          pH     BDecf      pCO2  ...    Peak_FHR     Peak_UC target
# 0    Normal  3.520000  6.000000  ...  193.000000  127.000000    1.0
# 1    Normal  2.500000  6.500000  ...  224.000000  127.000000    1.0
# 2    Normal  5.840000  6.600000  ...  174.500000  100.000000    1.0
# 3    Normal  2.720000  5.700000  ...  166.750000  100.000000    1.0
# 4    Normal  5.190000  5.500000  ...  229.000000  123.000000    1.0
# ..      ...       ...       ...  ...         ...         ...    ...
# 970  Normal  4.170062  6.214293  ...  200.142902   91.785073    0.0
# 971  Normal  3.440918  6.131623  ...  199.605552   99.390650    0.0
# 972  Normal  4.115599  7.287158  ...  187.137600  103.944945    0.0
# 973  Normal  6.115778  6.434896  ...  201.576821   71.489613    0.0
# 974  Normal  3.969773  6.191584  ...  199.995298   93.874249    0.0
#
# [975 rows x 42 columns]

# %%
df.pH.value_counts()
# Out:
# Normal          842
# Pathological    133
# Name: pH, dtype: int64

# %%
df.columns
# Out:
# Index(['pH', 'BDecf', 'pCO2', 'BE', 'Apgar1', 'Apgar5', 'Gest. Weeks',
#        'Weight(g)', 'Sex', 'Age', 'Gravidity', 'Parity', 'Diabetes',
#        'Hypertension', 'Preeclampsia', 'Liq.', 'Pyrexia', 'Meconium',
#        'Presentation', 'Induced', 'I.stage', 'NoProgress', 'CK/KP', 'II.stage',
#        'Deliv. type', 'dbID', 'Rec. type', 'Pos. II.st.', 'Sig2Birth',
#        'Mean_FHR', 'Mean_UC', 'Median_FHR', 'Median_UC', 'Std_FHR', 'Std_UC',
#        'RMS_FHR', 'RMS_UC', 'Peak_to_RMS_FHR', 'Peak_to_RMS_UC', 'Peak_FHR',
#        'Peak_UC', 'target'],
#       dtype='object')

# %%
pd.get_option("display.max_columns")
# Out:
# 0

# %%
df
# Out:
#          pH     BDecf      pCO2  ...    Peak_FHR     Peak_UC target
# 0    Normal  3.520000  6.000000  ...  193.000000  127.000000    1.0
# 1    Normal  2.500000  6.500000  ...  224.000000  127.000000    1.0
# 2    Normal  5.840000  6.600000  ...  174.500000  100.000000    1.0
# 3    Normal  2.720000  5.700000  ...  166.750000  100.000000    1.0
# 4    Normal  5.190000  5.500000  ...  229.000000  123.000000    1.0
# ..      ...       ...       ...  ...         ...         ...    ...
# 970  Normal  4.170062  6.214293  ...  200.142902   91.785073    0.0
# 971  Normal  3.440918  6.131623  ...  199.605552   99.390650    0.0
# 972  Normal  4.115599  7.287158  ...  187.137600  103.944945    0.0
# 973  Normal  6.115778  6.434896  ...  201.576821   71.489613    0.0
# 974  Normal  3.969773  6.191584  ...  199.995298   93.874249    0.0
#
# [975 rows x 42 columns]

# %%
df.shape
# Out:
# (975, 42)

# %%
# one hot encoding
dts = pd.get_dummies(df)
dts.head()
# Out:
#    BDecf  pCO2  ...  Apgar5_Excellent  Apgar5_ModeratelyAbnormal
# 0   3.52   6.0  ...                 1                          0
# 1   2.50   6.5  ...                 1                          0
# 2   5.84   6.6  ...                 1                          0
# 3   2.72   5.7  ...                 1                          0
# 4   5.19   5.5  ...                 1                          0
#
# [5 rows x 47 columns]

# %%
dts.shape
# Out:
# (975, 47)

# %%
dts.columns
# Out:
# Index(['BDecf', 'pCO2', 'BE', 'Gest. Weeks', 'Weight(g)', 'Sex', 'Age',
#        'Gravidity', 'Parity', 'Diabetes', 'Hypertension', 'Preeclampsia',
#        'Liq.', 'Pyrexia', 'Meconium', 'Presentation', 'Induced', 'I.stage',
#        'NoProgress', 'CK/KP', 'II.stage', 'Deliv. type', 'dbID', 'Rec. type',
#        'Pos. II.st.', 'Sig2Birth', 'Mean_FHR', 'Mean_UC', 'Median_FHR',
#        'Median_UC', 'Std_FHR', 'Std_UC', 'RMS_FHR', 'RMS_UC',
#        'Peak_to_RMS_FHR', 'Peak_to_RMS_UC', 'Peak_FHR', 'Peak_UC', 'target',
#        'pH_Normal', 'pH_Pathological', 'Apgar1_Attention', 'Apgar1_Excellent',
#        'Apgar1_ModeratelyAbnormal', 'Apgar5_Attention', 'Apgar5_Excellent',
#        'Apgar5_ModeratelyAbnormal'],
#       dtype='object')

# %% [markdown]
# #  Creating train and test set

# %%
X = dts.drop('target', axis=1)
y = dts['target']

# %%
X
# Out:
#         BDecf      pCO2  ...  Apgar5_Excellent  Apgar5_ModeratelyAbnormal
# 0    3.520000  6.000000  ...                 1                          0
# 1    2.500000  6.500000  ...                 1                          0
# 2    5.840000  6.600000  ...                 1                          0
# 3    2.720000  5.700000  ...                 1                          0
# 4    5.190000  5.500000  ...                 1                          0
# ..        ...       ...  ...               ...                        ...
# 970  4.170062  6.214293  ...                 1                          0
# 971  3.440918  6.131623  ...                 1                          0
# 972  4.115599  7.287158  ...                 1                          0
# 973  6.115778  6.434896  ...                 1                          0
# 974  3.969773  6.191584  ...                 1                          0
#
# [975 rows x 46 columns]

# %%
y
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 970    0.0
# 971    0.0
# 972    0.0
# 973    0.0
# 974    0.0
# Name: target, Length: 975, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)
print('Training dataset len: {}, Test data len: {}'.format(X_train.shape[0], y_test.shape[0]))
# Out:
# Training dataset len: 780, Test data len: 195

# %% [markdown]
# # Scaling values

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train.values)

# %%
X_test = sc.transform(X_test)

# %% [markdown]
# # Model Training

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 96.92%

# %%
print('Confusion matrix :- \n',confusion_matrix(y_test, predictions))
print("Classification Report :- \n",classification_report(y_test, predictions))
# Out:
# Confusion matrix :-
#  [[96  1]
#  [ 5 93]]
# Classification Report :-
#                precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97        97
#          1.0       0.99      0.95      0.97        98
#
#     accuracy                           0.97       195
#    macro avg       0.97      0.97      0.97       195
# weighted avg       0.97      0.97      0.97       195

# %%
fig, (ax) = plt.subplots(ncols=1, figsize=(15,15))
xgb.plot_importance(model, height=0.8, title="Features importance (XGBoost)", ax=ax, color="green") 
plt.show()

# %%
print("Important Features:")
for i in [30,22,1,3,36,26,16,29,5,4]:
    print(dts.columns[i])
# Out:
# Important Features:
# Std_FHR
# dbID
# pCO2
# Gest. Weeks
# Peak_FHR
# Mean_FHR
# Induced
# Median_UC
# Sex
# Weight(g)

# %% [markdown]
# # OPTIMIZE XGBOOST HYPERPARAMETERS BY PERFORMING GRID SEARCH

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'gamma': [1, 5],   # regularization parameter
              'subsample': [0.8, 1.0], # % of rows taken to build each tree
              'colsample_bytree': [0.8, 1.0], # number of columns used by each tree
              'max_depth': [7, 5], # depth of each tree
              'n_estimators': [100, 300] #no. of trees
             }

xgb_model = xgb.XGBClassifier(objective='binary:logistic', learning_rate = 0.01)
grid = GridSearchCV(xgb_model, 
                    param_grid, 
                    refit = True, 
                    verbose = 4
                   )
grid.fit(X_train, y_train)
print("Best Score: {:.2f} %".format(grid.best_score_ * 100))
print("Best Parameters:", grid.best_params_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.929, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.917, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.917, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.929, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.904, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.929, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.929, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.923, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.917, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.897, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.942, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.929, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.936, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.955, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.910, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.949, total=   0.7s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.929, total=   0.7s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.929, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.949, total=   0.7s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.904, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.897, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.910, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.910, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.929, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.878, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.910, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.923, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.910, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.923, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.897, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.942, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.929, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.929, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.942, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.904, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.955, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.936, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.904, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.891, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.917, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.904, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.929, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.885, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.923, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.923, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.891, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.923, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.897, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.917, total=   0.7s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.917, total=   0.7s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.936, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.936, total=   0.7s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.891, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.949, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.917, total=   0.7s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.936, total=   0.7s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.949, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.904, total=   0.6s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.885, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.910, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.897, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.936, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.885, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.897, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.917, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.891, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.917, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.891, total=   0.2s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.917, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.904, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.936, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.929, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.891, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.936, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.5s
# [CV] colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=0.8, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.897, total=   0.5s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.897, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.917, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.891, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.923, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=0.8, score=0.904, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.910, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.923, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.910, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.917, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=100, subsample=1.0, score=0.865, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.949, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.923, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.923, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.949, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=0.8, score=0.917, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.949, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.929, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.929, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.942, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=7, n_estimators=300, subsample=1.0, score=0.904, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.885, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.904, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.891, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.929, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=0.8, score=0.885, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.910, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.929, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.910, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.904, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=100, subsample=1.0, score=0.878, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.942, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.917, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.923, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.949, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=0.8, score=0.904, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.936, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=1, max_depth=5, n_estimators=300, subsample=1.0, score=0.897, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.878, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.904, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.885, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.929, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=0.8, score=0.891, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.917, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.917, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.885, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.923, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=100, subsample=1.0, score=0.859, total=   0.3s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.923, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.910, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.929, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.942, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=0.8, score=0.904, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.942, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.923, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.923, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.929, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=7, n_estimators=300, subsample=1.0, score=0.904, total=   0.8s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.878, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.910, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.885, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.929, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=0.8, score=0.885, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.910, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.917, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.885, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.897, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=100, subsample=1.0, score=0.878, total=   0.2s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.910, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.904, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.929, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.936, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=0.8, score=0.897, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.917, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.929, total=   0.6s
# [CV] colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0
# [CV]  colsample_bytree=1.0, gamma=5, max_depth=5, n_estimators=300, subsample=1.0, score=0.904, total=   0.6s
# [Parallel(n_jobs=1)]: Done 160 out of 160 | elapsed:  1.1min finished
# Best Score: 93.46 %
# Best Parameters: {'colsample_bytree': 0.8, 'gamma': 1, 'max_depth': 7, 'n_estimators': 300, 'subsample': 0.8}

# %%
print("Best Score: {:.2f} %".format(grid.best_score_ * 100))
print("Best Parameters:", grid.best_params_)
# Out:
# Best Score: 93.46 %
# Best Parameters: {'colsample_bytree': 0.8, 'gamma': 1, 'max_depth': 7, 'n_estimators': 300, 'subsample': 0.8}

# %%
grid_model = grid.best_estimator_

pred = grid_model.predict(X_test)

print("Accuracy {:.2f} %".format( 100 * accuracy_score(y_test, pred)))
# Testing Set Performance
print('Confusion matrix :- \n',confusion_matrix(y_test, pred))
print("Classification Report :- \n",classification_report(y_test, pred))
# Out:
# Accuracy 96.41 %
# Confusion matrix :-
#  [[95  2]
#  [ 5 93]]
# Classification Report :-
#                precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.96        97
#          1.0       0.98      0.95      0.96        98
#
#     accuracy                           0.96       195
#    macro avg       0.96      0.96      0.96       195
# weighted avg       0.96      0.96      0.96       195

# %% [markdown]
# # Performing K-fold Cross Validation on XGBoost model

# %%
from sklearn.model_selection import cross_val_score
# Hyper parameter tuned model by grid search
accuracies = cross_val_score(estimator = grid_model, X = sc.transform(X), y = y, cv = 10)
print("Accuracies of 10-flod cv:", accuracies)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracies of 10-flod cv: [0.7755102  0.96938776 0.86734694 0.96938776 0.96938776 0.94845361
#  0.94845361 0.93814433 0.95876289 0.96907216]
# Accuracy: 93.14 %
# Standard Deviation: 5.96 %

# %%
print("Accuracies of 10-flod cv:", accuracies)
print("Mean Accuracy of 10-folds: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation of 10-folds: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracies of 10-flod cv: [0.7755102  0.96938776 0.86734694 0.96938776 0.96938776 0.94845361
#  0.94845361 0.93814433 0.95876289 0.96907216]
# Mean Accuracy of 10-folds: 93.14 %
# Standard Deviation of 10-folds: 5.96 %

# %%
accuracies = cross_val_score(estimator = model, X = sc.transform(X), y = y, cv = 10)

# %%
print("Accuracies of 10-flod cv:", accuracies)
print("Mean Accuracy of 10-folds: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation of 10-folds: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracies of 10-flod cv: [0.7244898  0.97959184 0.97959184 0.95918367 0.95918367 0.94845361
#  0.97938144 0.94845361 0.95876289 0.98969072]
# Mean Accuracy of 10-folds: 94.27 %
# Standard Deviation of 10-folds: 7.40 %

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, pred)

# %%
auc = roc_auc_score(y_test, pred)

# %%
auc
# Out:
# 0.9641805175678518

# %%
xg_fpr, xg_tpr, _ = roc_curve(y_test, pred)

# %%
plt.plot(xg_fpr, xg_tpr, linestyle='--', label='xgboost')

# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plo

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr_probs = model.predict_proba(X_test)
lr_probs = lr_probs[:, 1]

# %%
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)

# %%
plt.plot(lr_fpr, lr_tpr, linestyle='--', label='logistic regression')

# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plo

# %%
plt.plot(xg_fpr, xg_tpr, linestyle='--', label='xgboost')
plt.plot(lr_fpr, lr_tpr, linestyle='--', label='logistic regression')

# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plo
